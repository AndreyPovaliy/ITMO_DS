# %% [markdown]
# # **Task 2 - загрузить датасет и сделать выборки в рамках требований**

# %% [markdown]
# # **Признаки датасета "Титаник" с их описанием:**
#
# **PassengerId:** Уникальный идентификатор пассажира.
#
# **Survived:** Выжил ли пассажир (1 - да, 0 - нет).
#
# **Pclass:** Класс пассажира (1 - Первый класс, 2 - Второй класс, 3 - Третий класс).
#
# **Name:** Имя пассажира.
#
# **Sex:** Пол пассажира (male - мужской, female - женский).
#
# **Age:** Возраст пассажира.
#
# **SibSp:** Количество братьев/сестер/супругов на борту.
#
# **Parch:** Количество родителей/детей на борту.
#
# **Ticket:** Номер билета.
#
# **Fare:** Стоимость билета.
#
# **Cabin:** Номер каюты.
#
# **Embarked:** Порт отправления (C - Cherbourg, Q - Queenstown, S - Southampton).

# %% [markdown]
# **Задание 1**

# %%
# здесь импортируйте пандас и датасет
import pandas as pd
import os 
os.chdir('/Users/andreypovaliy/Documents/Education/ITMO_DS/05_python_for_data_analysis/')

titanic = pd.read_csv('./lect/data/titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Задание №2**

# %% [markdown]
# 1) Выберите всех пассажиров первого класса: Найдите всех пассажиров, которые ехали в первом классе.
#
# 2) Найдите всех выживших пассажиров: Отберите строки, где пассажиры выжили .
#
# 3) Фильтрация по возрасту: Выберите всех пассажиров младше 18 лет.
#
# 4) Отбор по порту отправления: Найдите всех пассажиров, которые сели на корабль в Саутгемптоне.
#
# 5) Поиск по фамилии: Найдите всех пассажиров с фамилией, начинающейся на "Smith".
#
# 6) Отбор по стоимости билета: Отберите всех пассажиров, стоимость билета которых была больше 50.
#
# 7) Фильтрация по полу: Найдите всех пассажиров женского пола.
#
# 8) Отбор пассажиров с несколькими членами семьи на борту: Выберите всех пассажиров, у которых было больше 2 членов семьи на борту.
#
# 9) Поиск пассажиров с номером каюты: Найдите всех пассажиров, у которых указан номер каюты (Cabin не пустое значение).

# %%
# 1) Выберите всех пассажиров первого класса: Найдите всех пассажиров, которые ехали в первом классе.
titanic[titanic['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2) Найдите всех выживших пассажиров: Отберите строки, где пассажиры выжили .
titanic[titanic['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 3) Фильтрация по возрасту: Выберите всех пассажиров младше 18 лет.
titanic[titanic['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
# 4) Отбор по порту отправления: Найдите всех пассажиров, которые сели на корабль в Саутгемптоне.
titanic[titanic['Embarked'] == 'S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
# 5) Поиск по фамилии: Найдите всех пассажиров с фамилией, начинающейся на "Smith".
titanic.loc[titanic['Name'].str.match('Smith')]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 174          175         0       1     Smith, Mr. James Clinch    male  56.0
# 260          261         0       3           Smith, Mr. Thomas    male   NaN
# 284          285         0       1  Smith, Mr. Richard William    male   NaN
# 346          347         1       2   Smith, Miss. Marion Elsie  female  40.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 174      0      0   17764  30.6958    A7        C
# 260      0      0  384461   7.7500   NaN        Q
# 284      0      0  113056  26.0000   A19        S
# 346      0      0   31418  13.0000   NaN        S

# %%
# 6) Отбор по стоимости билета: Отберите всех пассажиров, стоимость билета которых была больше 50.
titanic[titanic['Fare'] > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 7) Фильтрация по полу: Найдите всех пассажиров женского пола.
titanic[titanic['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 8) Отбор пассажиров с несколькими членами семьи на борту: Выберите всех пассажиров, у которых было больше 2 членов семьи на борту.
titanic['families'] = titanic['SibSp'] + titanic['Parch']
titanic[titanic['families'] > 2]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# 25            26         1       3
# ..           ...       ...     ...
# 850          851         0       3
# 858          859         1       3
# 863          864         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 9) Поиск пассажиров с номером каюты: Найдите всех пассажиров, у которых указан номер каюты (Cabin не пустое значение).
titanic[titanic['Cabin'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Задание № 3**

# %% [markdown]
# 1) Выберите всех выживших пассажиров первого класса: Найдите всех пассажиров, которые ехали в первом классе и выжили.
#
# 2) Найдите всех несовершеннолетних, путешествовавших с родителями: Выберите пассажиров младше 18 лет, у которых было хотя бы одно количество родителей на борту.
#
# 3) Пассажиры с дорогими билетами и большим возрастом: Найдите всех пассажиров, возраст которых больше 50 лет и стоимость билета которых превышает 100.
#
# 4) Женщины, которые выжили и ехали из Квинстауна: Выберите женщин, которые выжили и сели на корабль в Квинстауне.
#
# 5) Мужчины третьего класса, путешествовавшие с братьями и сестрами: Найдите всех мужчин, которые ехали в третьем классе и имели хотя бы одного брата или сестру на борту.
#
# 6) Пассажиры второго класса с отсутствующим возрастом: Найдите всех пассажиров второго класса, у которых возраст не указан (Age is null).
#
# 7) Мужчины старше 30 лет, которые выжили: Выберите всех мужчин старше 30 лет, которые выжили.
#
# 8) Дети, ехавшие с обоими родителями: Найдите всех детей младше 12 лет, у которых было как минимум два родителя на борту.
#
# 9) Пассажиры старше 60 лет, ехавшие в первом классе, которые не выжили: Выберите всех пассажиров старше 60 лет, которые ехали в первом классе и не выжили.

# %%
# 1) Выберите всех выживших пассажиров первого класса: Найдите всех пассажиров, которые ехали в первом классе и выжили.

titanic[(titanic['Pclass'] == 1) & (titanic['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2) Найдите всех несовершеннолетних, путешествовавших с родителями: 
# Выберите пассажиров младше 18 лет, у которых было хотя бы одно количество родителей на борту.
titanic[(titanic['Age'] < 18) & (titanic['Parch'] != 0)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
# 3) Пассажиры с дорогими билетами и большим возрастом: 
# Найдите всех пассажиров, возраст которых больше 50 лет и стоимость билета которых превышает 100.
titanic[(titanic['Age'] > 50) & (titanic['Fare'] > 100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 195          196         1       1
# 268          269         1       1
# 438          439         0       1
# 659          660         0       1
#
#                                               Name     Sex   Age  SibSp  \
# 195                           Lurette, Miss. Elise  female  58.0      0
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 438                              Fortune, Mr. Mark    male  64.0      1
# 659                     Newell, Mr. Arthur Webster    male  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked  families
# 195      0  PC 17569  146.5208          B80        C         0
# 268      1  PC 17582  153.4625         C125        S         1
# 438      4     19950  263.0000  C23 C25 C27        S         5
# 659      2     35273  113.2750          D48        C         2

# %%
# 4) Женщины, которые выжили и ехали из Квинстауна: Выберите женщин, которые выжили и сели на корабль в Квинстауне.
titanic[(titanic['Sex'] == 'female') & (titanic['Embarked'] == 'C')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 31            32         1       1
# 39            40         1       3
# ..           ...       ...     ...
# 858          859         1       3
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 5) Мужчины третьего класса, путешествовавшие с братьями и сестрами: 
# Найдите всех мужчин, которые ехали в третьем классе и имели хотя бы одного брата или сестру на борту.
titanic[(titanic['Sex'] == 'male') & (titanic['SibSp'] != 0)]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 27            28         0       1           Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                      ...
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 860          861         0       3                  Hansen, Mr. Claus Peter
# 861          862         0       2              Giles, Mr. Frederick Edward
# 869          870         1       3          Johnson, Master. Harold Theodor
#
# ...

# %%
# 6) Пассажиры второго класса с отсутствующим возрастом: 
# Найдите всех пассажиров второго класса, у которых возраст не указан (Age is null).
titanic[(titanic['Pclass'] == 2) & (titanic['Age'].isna())]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 17            18         1       2      Williams, Mr. Charles Eugene    male
# 181          182         0       2                  Pernot, Mr. Rene    male
# 277          278         0       2       Parkes, Mr. Francis "Frank"    male
# 303          304         1       2               Keane, Miss. Nora A  female
# 413          414         0       2    Cunningham, Mr. Alfred Fleming    male
# 466          467         0       2             Campbell, Mr. William    male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"    male
# 547          548         1       2        Padro y Manent, Mr. Julian    male
# 596          597         1       2        Leitch, Miss. Jessie Wills  female
# 674          675         0       2        Watson, Mr. Ennis Hastings    male
# 732          733         0       2              Knight, Mr. Robert J    male
#
# ...

# %%
# 7) Мужчины старше 30 лет, которые выжили: Выберите всех мужчин старше 30 лет, которые выжили.
titanic[(titanic['Age'] > 30) & (titanic['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 8) Дети, ехавшие с обоими родителями: Найдите всех детей младше 12 лет, у которых было как минимум два родителя на борту.
titanic[(titanic['Age'] < 12) & (titanic['Parch'] == 2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 43            44         1       2
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 78            79         1       2
# 119          120         0       3
# 147          148         0       3
# 165          166         1       3
# 182          183         0       3
# 184          185         1       3
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 297          298         0       1
# 305          306         1       1
# 381          382         1       3
# 386          387         0       3
# 419          420         0       3
# 445          446         1       1
# 480          481         0       3
# 535          536         1       2
# 541          542         0       3
# 542          543         0       3
# 634          635         0       3
# 642          643         0       3
# ...

# %%
# 9) Пассажиры старше 60 лет, ехавшие в первом классе, которые не выжили: 
# Выберите всех пассажиров старше 60 лет, которые ехали в первом классе и не выжили.
titanic[(titanic['Age'] > 60) & (titanic['Pclass'] == 1) & (titanic['Survived'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 170          171         0       1       Van der hoef, Mr. Wyckoff  male
# 252          253         0       1       Stead, Mr. William Thomas  male
# 438          439         0       1               Fortune, Mr. Mark  male
# 456          457         0       1       Millet, Mr. Francis Davis  male
# 493          494         0       1         Artagaveytia, Mr. Ramon  male
# 545          546         0       1    Nicholson, Mr. Arthur Ernest  male
# 555          556         0       1              Wright, Mr. George  male
# 625          626         0       1           Sutton, Mr. Frederick  male
# 745          746         0       1    Crosby, Capt. Edward Gifford  male
#
#       Age  SibSp  Parch     Ticket      Fare        Cabin Embarked  families
# ...
