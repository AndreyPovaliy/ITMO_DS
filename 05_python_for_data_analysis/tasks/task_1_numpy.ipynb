# %% [markdown]
# # Задание №1 для самостоятельной работы
#
# ---

# %% [markdown]
# # Усечённое среднее
#
# Усечённое среднее вычисляется путем отбрасывания $ p $ наименьших и $ p $ наибольших значений из упорядоченной выборки. Пусть даны отсортированные значения:
#
# $
# x_{(1)}, x_{(2)}, \dots, x_{(n)}
# $
#
# где $ x_{(1)} $ — наименьшее значение, а $x_{(n)} $ — наибольшее.
#
# Тогда усечённое среднее с параметром $ p $ определяется как:
#
# $
# \bar{x}_c = \frac{1}{n - 2p} \sum_{i=p+1}^{n-p} x_{(i)}
# $
#
# где:
#
# - $\ n $ — общее число элементов в выборке,
# - $\ p $ — количество отбрасываемых значений с каждого края,
# - $x_{(i)} $ — упорядоченные значения.
#
# Этот метод позволяет снизить влияние выбросов на расчет среднего значения.
#
#
#
# ```
# Например, в международных состязаниях по прыжкам в воду
# верхние и нижние баллы пяти судей отбрасываются, и итоговым баллом
# является среднеарифметический балл трех оставшихся судей.
# Такой подход не дает одному судье манипулировать баллом,
# возможно, чтобы оказать содействие спортсмену из своей страны.
#
# На Олимпийских играх, чемпионатах и Кубках мира прыжки оценивают
# 7 судей.
#
# Прыжок оценивается по 10-балльной системе:
# - от 0 (низшая оценка) до 10 (высшая).
# - При выведении общей оценки за прыжок высшая и низшая оценки отбрасываются
# - Оставшиеся суммируются и умножаются на коэффициент сложности прыжка (от 1,2 до 3,6).
# - Полученный результат умножается на 0,6.
#
# ```

# %% [markdown]
# ## Задание

# %% [markdown]
# Создать функцию `trim_mean_dive`, для реализации вышеизложенного примера о международных соренованиях по прыжкам вводу.
#
# В процессе работы над функцией применить библиотеку `numpy`
#
# Сигнатура функции:
#
#
# ``` python
# def trim_mean_dive(points: np.array, hard_coef=1.2: float) -> float:
#     return final_score
# ```

# %%
import numpy as np
from scipy. stats import trim_mean
# ваш код здесь

def trim_mean_dive(points: np.array, hard_coef=1.2) -> float:
    return trim_mean(points, hard_coef)
