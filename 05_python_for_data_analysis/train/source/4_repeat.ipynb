# %% [markdown]
# # Уборка в данных: Решение структурных проблем в наборах данных
#
# **Определение аккуратных данных**
#
# * Каждая переменная образует столбец и содержит значения.
# * Каждое наблюдение образует строку.
# * Каждый объект наблюдения составляет таблицу.
#
# **Принцип от большего (проблемы в структуре) --> к меньшему (проблемы в значениях)**

# %% [markdown]
# ## "Большие" проблемы
#
# ✅ Заголовки столбцов - это значения, а не имена переменных.
#
# ✅ Несколько переменных хранятся в одном столбце.
#
# ✅ В одной таблице хранятся несколько единиц объектов наблюдения (observational units).
#
# ✅ Одна единица наблюдения хранится в нескольких таблицах.

# %%
import pandas as pd
import os
os.chdir('/Users/andreypovaliy/Documents/Education/ITMO_DS/05_python_for_data_analysis/')

# %% [markdown]
# ## **Заголовки столбцов это значения, а не имена переменных - пример:**

# %%
df = pd.read_csv("./lect/data/relig.csv")
df
# Out:
#                   religion   <$10k   $10-20k  $20-30k  $30-40k   $40-50k  \
# 0                 Agnostic      27        34       60       81        76
# 1                  Atheist      12        27       37       52        35
# 2                 Buddhist      27        21       30       34        33
# 3                 Catholic     418       617      732      670       638
# 4        Dont know/refused      15        14       15       11        10
# 5         Evangelical Prot     575       869     1064      982       881
# 6                   Hindu        1         9        7        9        11
# 7  Historically Black Prot     228       244      236      238       197
# 8         Jehovahs Witness      20        27       24       24        21
# 9                   Jewish      19        19       25       25        30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   religion  10 non-null     object
#  1    <$10k    10 non-null     int64
#  2    $10-20k  10 non-null     int64
#  3   $20-30k   10 non-null     int64
#  4   $30-40k   10 non-null     int64
#  5    $40-50k  10 non-null     int64
#  6   $50-75k   10 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 688.0+ bytes

# %%
#  перевернуть (unpivots) фрейм данных (DataFrame) из широкого формата (wide format) в длинный (long format). formatted_df

formatted_df = pd.melt(df, id_vars=["religion"], var_name="income", value_name="count")
formatted_df
# Out:
#                    religion    income  count
# 0                  Agnostic     <$10k     27
# 1                   Atheist     <$10k     12
# 2                  Buddhist     <$10k     27
# 3                  Catholic     <$10k    418
# 4         Dont know/refused     <$10k     15
# 5          Evangelical Prot     <$10k    575
# 6                    Hindu      <$10k      1
# 7   Historically Black Prot     <$10k    228
# 8          Jehovahs Witness     <$10k     20
# 9                    Jewish     <$10k     19
# 10                 Agnostic   $10-20k     34
# 11                  Atheist   $10-20k     27
# 12                 Buddhist   $10-20k     21
# 13                 Catholic   $10-20k    617
# 14        Dont know/refused   $10-20k     14
# 15         Evangelical Prot   $10-20k    869
# 16                   Hindu    $10-20k      9
# 17  Historically Black Prot   $10-20k    244
# 18         Jehovahs Witness   $10-20k     27
# 19                   Jewish   $10-20k     19
# 20                 Agnostic   $20-30k     60
# 21                  Atheist   $20-30k     37
# 22                 Buddhist   $20-30k     30
# 23                 Catholic   $20-30k    732
# 24        Dont know/refused   $20-30k     15
# 25         Evangelical Prot   $20-30k   1064
# 26                   Hindu    $20-30k      7
# 27  Historically Black Prot   $20-30k    236
# 28         Jehovahs Witness   $20-30k     24
# 29                   Jewish   $20-30k     25
# 30                 Agnostic   $30-40k     81
# 31                  Atheist   $30-40k     52
# 32                 Buddhist   $30-40k     34
# 33                 Catholic   $30-40k    670
# 34        Dont know/refused   $30-40k     11
# 35         Evangelical Prot   $30-40k    982
# 36                   Hindu    $30-40k      9
# 37  Historically Black Prot   $30-40k    238
# 38         Jehovahs Witness   $30-40k     24
# 39                   Jewish   $30-40k     25
# 40                 Agnostic   $40-50k     76
# 41                  Atheist   $40-50k     35
# 42                 Buddhist   $40-50k     33
# 43                 Catholic   $40-50k    638
# 44        Dont know/refused   $40-50k     10
# 45         Evangelical Prot   $40-50k    881
# 46                   Hindu    $40-50k     11
# 47  Historically Black Prot   $40-50k    197
# 48         Jehovahs Witness   $40-50k     21
# 49                   Jewish   $40-50k     30
# 50                 Agnostic   $50-75k    137
# 51                  Atheist   $50-75k     70
# 52                 Buddhist   $50-75k     58
# 53                 Catholic   $50-75k   1116
# 54        Dont know/refused   $50-75k     35
# 55         Evangelical Prot   $50-75k   1486
# 56                   Hindu    $50-75k     34
# 57  Historically Black Prot   $50-75k    223
# 58         Jehovahs Witness   $50-75k     30
# 59                   Jewish   $50-75k     95

# %%
# отсортировать по низходящей formatted_df
formatted_df = formatted_df.sort_values(by=["count"], ascending=False)

# %%
# выводим аккуратную версию набора данных:
formatted_df
# Out:
#                    religion    income  count
# 55         Evangelical Prot   $50-75k   1486
# 53                 Catholic   $50-75k   1116
# 25         Evangelical Prot   $20-30k   1064
# 35         Evangelical Prot   $30-40k    982
# 45         Evangelical Prot   $40-50k    881
# 15         Evangelical Prot   $10-20k    869
# 23                 Catholic   $20-30k    732
# 33                 Catholic   $30-40k    670
# 43                 Catholic   $40-50k    638
# 13                 Catholic   $10-20k    617
# 5          Evangelical Prot     <$10k    575
# 3                  Catholic     <$10k    418
# 17  Historically Black Prot   $10-20k    244
# 37  Historically Black Prot   $30-40k    238
# 27  Historically Black Prot   $20-30k    236
# 7   Historically Black Prot     <$10k    228
# 57  Historically Black Prot   $50-75k    223
# 47  Historically Black Prot   $40-50k    197
# 50                 Agnostic   $50-75k    137
# 59                   Jewish   $50-75k     95
# 30                 Agnostic   $30-40k     81
# 40                 Agnostic   $40-50k     76
# 51                  Atheist   $50-75k     70
# 20                 Agnostic   $20-30k     60
# 52                 Buddhist   $50-75k     58
# 31                  Atheist   $30-40k     52
# 21                  Atheist   $20-30k     37
# 54        Dont know/refused   $50-75k     35
# 41                  Atheist   $40-50k     35
# 56                   Hindu    $50-75k     34
# 32                 Buddhist   $30-40k     34
# 10                 Agnostic   $10-20k     34
# 42                 Buddhist   $40-50k     33
# 22                 Buddhist   $20-30k     30
# 58         Jehovahs Witness   $50-75k     30
# 49                   Jewish   $40-50k     30
# 18         Jehovahs Witness   $10-20k     27
# 2                  Buddhist     <$10k     27
# 11                  Atheist   $10-20k     27
# 0                  Agnostic     <$10k     27
# 29                   Jewish   $20-30k     25
# 39                   Jewish   $30-40k     25
# 38         Jehovahs Witness   $30-40k     24
# 28         Jehovahs Witness   $20-30k     24
# 12                 Buddhist   $10-20k     21
# 48         Jehovahs Witness   $40-50k     21
# 8          Jehovahs Witness     <$10k     20
# 19                   Jewish   $10-20k     19
# 9                    Jewish     <$10k     19
# 4         Dont know/refused     <$10k     15
# 24        Dont know/refused   $20-30k     15
# 14        Dont know/refused   $10-20k     14
# 1                   Atheist     <$10k     12
# 34        Dont know/refused   $30-40k     11
# 46                   Hindu    $40-50k     11
# 44        Dont know/refused   $40-50k     10
# 16                   Hindu    $10-20k      9
# 36                   Hindu    $30-40k      9
# 26                   Hindu    $20-30k      7
# 6                    Hindu      <$10k      1

# %%
# formatted_df вывести 10 чтрок

formatted_df.head(10)
# Out:
#             religion    income  count
# 55  Evangelical Prot   $50-75k   1486
# 53          Catholic   $50-75k   1116
# 25  Evangelical Prot   $20-30k   1064
# 35  Evangelical Prot   $30-40k    982
# 45  Evangelical Prot   $40-50k    881
# 15  Evangelical Prot   $10-20k    869
# 23          Catholic   $20-30k    732
# 33          Catholic   $30-40k    670
# 43          Catholic   $40-50k    638
# 13          Catholic   $10-20k    617

# %%
# вывести информацию
formatted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 55 to 6
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   religion  60 non-null     object
#  1   income    60 non-null     object
#  2   count     60 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# ## **Другой пример:**

# %%
df = pd.read_csv("./lect/data/billboard.csv")
df
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
#     genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0    Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1    Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2    Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3    Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4    Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
# ..    ...          ...         ...        ...        ...        ...  ...
# 312   R&B   2000-08-05  2000-08-05         98        NaN        NaN  ...
# 313   Rap   2000-02-12  2000-02-12         99       99.0       99.0  ...
# 314  Rock   2000-09-02  2000-09-02         99       99.0        NaN  ...
# 315   Rap   2000-07-01  2000-07-01         99       99.0        NaN  ...
# 316   R&B   2000-10-28  2000-10-28         99        NaN        NaN  ...
#
#      x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 312         NaN         NaN         NaN         NaN         NaN         NaN
# 313         NaN         NaN         NaN         NaN         NaN         NaN
# 314         NaN         NaN         NaN         NaN         NaN         NaN
# 315         NaN         NaN         NaN         NaN         NaN         NaN
# 316         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x73rd.week  x74th.week  x75th.week  x76th.week
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 312         NaN         NaN         NaN         NaN
# 313         NaN         NaN         NaN         NaN
# 314         NaN         NaN         NaN         NaN
# 315         NaN         NaN         NaN         NaN
# 316         NaN         NaN         NaN         NaN
#
# [317 rows x 83 columns]

# %%
# вывести инфоормацию
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             317 non-null    int64
#  1   artist.inverted  317 non-null    object
#  2   track            317 non-null    object
#  3   time             317 non-null    object
#  4   genre            317 non-null    object
#  5   date.entered     317 non-null    object
#  6   date.peaked      317 non-null    object
#  7   x1st.week        317 non-null    int64
#  8   x2nd.week        312 non-null    float64
#  9   x3rd.week        307 non-null    float64
#  10  x4th.week        300 non-null    float64
#  11  x5th.week        292 non-null    float64
#  12  x6th.week        280 non-null    float64
#  13  x7th.week        269 non-null    float64
#  14  x8th.week        260 non-null    float64
#  15  x9th.week        253 non-null    float64
#  16  x10th.week       244 non-null    float64
#  17  x11th.week       236 non-null    float64
#  18  x12th.week       222 non-null    float64
#  19  x13th.week       210 non-null    float64
#  20  x14th.week       204 non-null    float64
#  21  x15th.week       197 non-null    float64
#  22  x16th.week       182 non-null    float64
#  23  x17th.week       177 non-null    float64
#  24  x18th.week       166 non-null    float64
#  25  x19th.week       156 non-null    float64
#  26  x20th.week       146 non-null    float64
#  27  x21st.week       65 non-null     float64
#  28  x22nd.week       55 non-null     float64
#  29  x23rd.week       48 non-null     float64
#  30  x24th.week       46 non-null     float64
#  31  x25th.week       38 non-null     float64
#  32  x26th.week       36 non-null     float64
#  33  x27th.week       29 non-null     float64
#  34  x28th.week       24 non-null     float64
#  35  x29th.week       20 non-null     float64
#  36  x30th.week       20 non-null     float64
#  37  x31st.week       19 non-null     float64
#  38  x32nd.week       18 non-null     float64
#  39  x33rd.week       12 non-null     float64
#  40  x34th.week       10 non-null     float64
#  41  x35th.week       9 non-null      float64
#  42  x36th.week       9 non-null      float64
#  43  x37th.week       9 non-null      float64
#  44  x38th.week       8 non-null      float64
#  45  x39th.week       8 non-null      float64
#  46  x40th.week       7 non-null      float64
#  47  x41st.week       7 non-null      float64
#  48  x42nd.week       6 non-null      float64
#  49  x43rd.week       6 non-null      float64
#  50  x44th.week       6 non-null      float64
#  51  x45th.week       5 non-null      float64
#  52  x46th.week       5 non-null      float64
#  53  x47th.week       5 non-null      float64
#  54  x48th.week       4 non-null      float64
#  55  x49th.week       4 non-null      float64
#  56  x50th.week       4 non-null      float64
#  57  x51st.week       4 non-null      float64
#  58  x52nd.week       4 non-null      float64
#  59  x53rd.week       4 non-null      float64
#  60  x54th.week       2 non-null      float64
#  61  x55th.week       2 non-null      float64
#  62  x56th.week       2 non-null      float64
#  63  x57th.week       2 non-null      float64
#  64  x58th.week       2 non-null      float64
#  65  x59th.week       2 non-null      float64
#  66  x60th.week       2 non-null      float64
#  67  x61st.week       2 non-null      float64
#  68  x62nd.week       2 non-null      float64
#  69  x63rd.week       2 non-null      float64
#  70  x64th.week       2 non-null      float64
#  71  x65th.week       1 non-null      float64
#  72  x66th.week       0 non-null      float64
#  73  x67th.week       0 non-null      float64
#  74  x68th.week       0 non-null      float64
#  75  x69th.week       0 non-null      float64
#  76  x70th.week       0 non-null      float64
#  77  x71st.week       0 non-null      float64
#  78  x72nd.week       0 non-null      float64
#  79  x73rd.week       0 non-null      float64
#  80  x74th.week       0 non-null      float64
#  81  x75th.week       0 non-null      float64
#  82  x76th.week       0 non-null      float64
# dtypes: float64(75), int64(2), object(6)
# memory usage: 205.7+ KB

# %%
# вывести колонки
df.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
#        'x55th.week', 'x56th.week', 'x57th.week', 'x58th.week', 'x59th.week',
#        'x60th.week', 'x61st.week', 'x62nd.week', 'x63rd.week', 'x64th.week',
#        'x65th.week', 'x66th.week', 'x67th.week', 'x68th.week', 'x69th.week',
#        'x70th.week', 'x71st.week', 'x72nd.week', 'x73rd.week', 'x74th.week',
#        'x75th.week', 'x76th.week'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             317 non-null    int64
#  1   artist.inverted  317 non-null    object
#  2   track            317 non-null    object
#  3   time             317 non-null    object
#  4   genre            317 non-null    object
#  5   date.entered     317 non-null    object
#  6   date.peaked      317 non-null    object
#  7   x1st.week        317 non-null    int64
#  8   x2nd.week        312 non-null    float64
#  9   x3rd.week        307 non-null    float64
#  10  x4th.week        300 non-null    float64
#  11  x5th.week        292 non-null    float64
#  12  x6th.week        280 non-null    float64
#  13  x7th.week        269 non-null    float64
#  14  x8th.week        260 non-null    float64
#  15  x9th.week        253 non-null    float64
#  16  x10th.week       244 non-null    float64
#  17  x11th.week       236 non-null    float64
#  18  x12th.week       222 non-null    float64
#  19  x13th.week       210 non-null    float64
#  20  x14th.week       204 non-null    float64
#  21  x15th.week       197 non-null    float64
#  22  x16th.week       182 non-null    float64
#  23  x17th.week       177 non-null    float64
#  24  x18th.week       166 non-null    float64
#  25  x19th.week       156 non-null    float64
#  26  x20th.week       146 non-null    float64
#  27  x21st.week       65 non-null     float64
#  28  x22nd.week       55 non-null     float64
#  29  x23rd.week       48 non-null     float64
#  30  x24th.week       46 non-null     float64
#  31  x25th.week       38 non-null     float64
#  32  x26th.week       36 non-null     float64
#  33  x27th.week       29 non-null     float64
#  34  x28th.week       24 non-null     float64
#  35  x29th.week       20 non-null     float64
#  36  x30th.week       20 non-null     float64
#  37  x31st.week       19 non-null     float64
#  38  x32nd.week       18 non-null     float64
#  39  x33rd.week       12 non-null     float64
#  40  x34th.week       10 non-null     float64
#  41  x35th.week       9 non-null      float64
#  42  x36th.week       9 non-null      float64
#  43  x37th.week       9 non-null      float64
#  44  x38th.week       8 non-null      float64
#  45  x39th.week       8 non-null      float64
#  46  x40th.week       7 non-null      float64
#  47  x41st.week       7 non-null      float64
#  48  x42nd.week       6 non-null      float64
#  49  x43rd.week       6 non-null      float64
#  50  x44th.week       6 non-null      float64
#  51  x45th.week       5 non-null      float64
#  52  x46th.week       5 non-null      float64
#  53  x47th.week       5 non-null      float64
#  54  x48th.week       4 non-null      float64
#  55  x49th.week       4 non-null      float64
#  56  x50th.week       4 non-null      float64
#  57  x51st.week       4 non-null      float64
#  58  x52nd.week       4 non-null      float64
#  59  x53rd.week       4 non-null      float64
#  60  x54th.week       2 non-null      float64
#  61  x55th.week       2 non-null      float64
#  62  x56th.week       2 non-null      float64
#  63  x57th.week       2 non-null      float64
#  64  x58th.week       2 non-null      float64
#  65  x59th.week       2 non-null      float64
#  66  x60th.week       2 non-null      float64
#  67  x61st.week       2 non-null      float64
#  68  x62nd.week       2 non-null      float64
#  69  x63rd.week       2 non-null      float64
#  70  x64th.week       2 non-null      float64
#  71  x65th.week       1 non-null      float64
#  72  x66th.week       0 non-null      float64
#  73  x67th.week       0 non-null      float64
#  74  x68th.week       0 non-null      float64
#  75  x69th.week       0 non-null      float64
#  76  x70th.week       0 non-null      float64
#  77  x71st.week       0 non-null      float64
#  78  x72nd.week       0 non-null      float64
#  79  x73rd.week       0 non-null      float64
#  80  x74th.week       0 non-null      float64
#  81  x75th.week       0 non-null      float64
#  82  x76th.week       0 non-null      float64
# dtypes: float64(75), int64(2), object(6)
# memory usage: 205.7+ KB

# %%
# выполнить Melting по неделе и рангу
id_vars = ["year", "artist.inverted", "track", "time", "genre", "date.entered", "date.peaked"]

df = pd.melt(frame=df, id_vars=id_vars, var_name="week", value_name="rank")
df
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 24087  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 24088  2000          Smith, Will                            Freakin' It  3:58
# 24089  2000        Zombie Nation                          Kernkraft 400  3:30
# 24090  2000       Eastsidaz, The                               Got Beef  3:58
# 24091  2000               Fragma                         Toca's Miracle  3:22
#
#       genre date.entered date.peaked        week  rank
# 0      Rock   2000-09-23  2000-11-18   x1st.week  78.0
# 1      Rock   2000-02-12  2000-04-08   x1st.week  15.0
# 2      Rock   1999-10-23  2000-01-29   x1st.week  71.0
# 3      Rock   2000-08-12  2000-09-16   x1st.week  41.0
# 4      Rock   2000-08-05  2000-10-14   x1st.week  57.0
# ...     ...          ...         ...         ...   ...
# 24087   R&B   2000-08-05  2000-08-05  x76th.week   NaN
# 24088   Rap   2000-02-12  2000-02-12  x76th.week   NaN
# 24089  Rock   2000-09-02  2000-09-02  x76th.week   NaN
# 24090   Rap   2000-07-01  2000-07-01  x76th.week   NaN
# 24091   R&B   2000-10-28  2000-10-28  x76th.week   NaN
#
# [24092 rows x 9 columns]

# %%
# вывести информацию
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             24092 non-null  int64
#  1   artist.inverted  24092 non-null  object
#  2   track            24092 non-null  object
#  3   time             24092 non-null  object
#  4   genre            24092 non-null  object
#  5   date.entered     24092 non-null  object
#  6   date.peaked      24092 non-null  object
#  7   week             24092 non-null  object
#  8   rank             5307 non-null   float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.7+ MB

# %%
# очистить week и првести в int
df["week"] = df['week'].str.extract('(\d+)')
df['week']= df["week"].astype(int) # приведение к числу
df
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 24087  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 24088  2000          Smith, Will                            Freakin' It  3:58
# 24089  2000        Zombie Nation                          Kernkraft 400  3:30
# 24090  2000       Eastsidaz, The                               Got Beef  3:58
# 24091  2000               Fragma                         Toca's Miracle  3:22
#
#       genre date.entered date.peaked  week  rank
# 0      Rock   2000-09-23  2000-11-18     1  78.0
# 1      Rock   2000-02-12  2000-04-08     1  15.0
# 2      Rock   1999-10-23  2000-01-29     1  71.0
# 3      Rock   2000-08-12  2000-09-16     1  41.0
# 4      Rock   2000-08-05  2000-10-14     1  57.0
# ...     ...          ...         ...   ...   ...
# 24087   R&B   2000-08-05  2000-08-05    76   NaN
# 24088   Rap   2000-02-12  2000-02-12    76   NaN
# 24089  Rock   2000-09-02  2000-09-02    76   NaN
# 24090   Rap   2000-07-01  2000-07-01    76   NaN
# 24091   R&B   2000-10-28  2000-10-28    76   NaN
#
# [24092 rows x 9 columns]

# %%
# сделать subset только по треку 'Music'
df_filtred = df[df['track'] == 'Music']
df_filtred.tail(10)
# Out:
# track
# Music    76
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             24092 non-null  int64
#  1   artist.inverted  24092 non-null  object
#  2   track            24092 non-null  object
#  3   time             24092 non-null  object
#  4   genre            24092 non-null  object
#  5   date.entered     24092 non-null  object
#  6   date.peaked      24092 non-null  object
#  7   week             24092 non-null  int64
#  8   rank             5307 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.7+ MB

# %%
df['date'] = pd.to_datetime(df['date.entered']) + pd.to_timedelta(df['week'], unit='w') - pd.DateOffset(weeks=1)

# %%
pd.to_datetime(df['date.entered'])
# Out:
# 0       2000-09-23
# 1       2000-02-12
# 2       1999-10-23
# 3       2000-08-12
# 4       2000-08-05
#            ...
# 24087   2000-08-05
# 24088   2000-02-12
# 24089   2000-09-02
# 24090   2000-07-01
# 24091   2000-10-28
# Name: date.entered, Length: 24092, dtype: datetime64[ns]

# %%
pd.to_datetime(df['date.entered']) + pd.to_timedelta(df['week'], unit='w')
# Out:
# 0       2000-09-30
# 1       2000-02-19
# 2       1999-10-30
# 3       2000-08-19
# 4       2000-08-12
#            ...
# 24087   2002-01-19
# 24088   2001-07-28
# 24089   2002-02-16
# 24090   2001-12-15
# 24091   2002-04-13
# Length: 24092, dtype: datetime64[ns]

# %%
df_filtred = df[df['track'] == 'Music']
df_filtred
# Out:
#        year artist.inverted  track  time genre date.entered date.peaked  week  \
# 3      2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     1
# 320    2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     2
# 637    2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     3
# 954    2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     4
# 1271   2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     5
# ...     ...             ...    ...   ...   ...          ...         ...   ...
# 22510  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    72
# 22827  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    73
# 23144  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    74
# 23461  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    75
# 23778  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    76
#
#        rank       date
# 3      41.0 2000-08-12
# 320    23.0 2000-08-19
# 637    18.0 2000-08-26
# 954    14.0 2000-09-02
# 1271    2.0 2000-09-09
# ...     ...        ...
# 22510   NaN 2001-12-22
# 22827   NaN 2001-12-29
# 23144   NaN 2002-01-05
# 23461   NaN 2002-01-12
# 23778   NaN 2002-01-19
#
# [76 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             24092 non-null  int64
#  1   artist.inverted  24092 non-null  object
#  2   track            24092 non-null  object
#  3   time             24092 non-null  object
#  4   genre            24092 non-null  object
#  5   date.entered     24092 non-null  object
#  6   date.peaked      24092 non-null  object
#  7   week             24092 non-null  int64
#  8   rank             5307 non-null   float64
#  9   date             24092 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 1.8+ MB

# %%
df = df.dropna()
df
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 19663  2000             Lonestar                                 Amazed  4:25
# 19700  2000                Creed                                 Higher  5:16
# 19980  2000             Lonestar                                 Amazed  4:25
# 20017  2000                Creed                                 Higher  5:16
# 20334  2000                Creed                                 Higher  5:16
#
#          genre date.entered date.peaked  week  rank       date
# 0         Rock   2000-09-23  2000-11-18     1  78.0 2000-09-23
# 1         Rock   2000-02-12  2000-04-08     1  15.0 2000-02-12
# 2         Rock   1999-10-23  2000-01-29     1  71.0 1999-10-23
# 3         Rock   2000-08-12  2000-09-16     1  41.0 2000-08-12
# 4         Rock   2000-08-05  2000-10-14     1  57.0 2000-08-05
# ...        ...          ...         ...   ...   ...        ...
# 19663  Country   1999-06-05  2000-03-04    63  45.0 2000-08-12
# 19700     Rock   1999-09-11  2000-07-22    63  50.0 2000-11-18
# 19980  Country   1999-06-05  2000-03-04    64  50.0 2000-08-19
# 20017     Rock   1999-09-11  2000-07-22    64  50.0 2000-11-25
# 20334     Rock   1999-09-11  2000-07-22    65  49.0 2000-12-02
#
# [5307 rows x 10 columns]

# %%
df_filtred = df[df['track'] == 'Music']
df_filtred
# Out:
#       year artist.inverted  track  time genre date.entered date.peaked  week  \
# 3     2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     1
# 320   2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     2
# 637   2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     3
# 954   2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     4
# 1271  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     5
# 1588  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     6
# 1905  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     7
# 2222  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     8
# 2539  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16     9
# 2856  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    10
# 3173  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    11
# 3490  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    12
# 3807  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    13
# 4124  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    14
# 4441  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    15
# 4758  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    16
# 5075  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    17
# 5392  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    18
# 5709  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    19
# 6026  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    20
# 6343  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    21
# 6660  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    22
# 6977  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    23
# 7294  2000         Madonna  Music  3:45  Rock   2000-08-12  2000-09-16    24
#
#       rank       date
# 3     41.0 2000-08-12
# 320   23.0 2000-08-19
# 637   18.0 2000-08-26
# 954   14.0 2000-09-02
# 1271   2.0 2000-09-09
# 1588   1.0 2000-09-16
# 1905   1.0 2000-09-23
# 2222   1.0 2000-09-30
# 2539   1.0 2000-10-07
# 2856   2.0 2000-10-14
# 3173   2.0 2000-10-21
# 3490   2.0 2000-10-28
# 3807   2.0 2000-11-04
# 4124   2.0 2000-11-11
# 4441   4.0 2000-11-18
# 4758   8.0 2000-11-25
# 5075  11.0 2000-12-02
# 5392  16.0 2000-12-09
# 5709  20.0 2000-12-16
# 6026  25.0 2000-12-23
# 6343  27.0 2000-12-30
# 6660  27.0 2001-01-06
# 6977  29.0 2001-01-13
# 7294  44.0 2001-01-20

# %%
df_new = df[['artist.inverted', 'track', 'date', 'week','rank']]

# %%
df_new.reset_index(inplace=True)

# %%
df_new
# Out:
#       index      artist.inverted                                  track  \
# 0         0      Destiny's Child               Independent Women Part I
# 1         1              Santana                           Maria, Maria
# 2         2        Savage Garden                     I Knew I Loved You
# 3         3              Madonna                                  Music
# 4         4  Aguilera, Christina  Come On Over Baby (All I Want Is You)
# ...     ...                  ...                                    ...
# 5302  19663             Lonestar                                 Amazed
# 5303  19700                Creed                                 Higher
# 5304  19980             Lonestar                                 Amazed
# 5305  20017                Creed                                 Higher
# 5306  20334                Creed                                 Higher
#
#            date  week  rank
# 0    2000-09-23     1  78.0
# 1    2000-02-12     1  15.0
# 2    1999-10-23     1  71.0
# 3    2000-08-12     1  41.0
# 4    2000-08-05     1  57.0
# ...         ...   ...   ...
# 5302 2000-08-12    63  45.0
# 5303 2000-11-18    63  50.0
# 5304 2000-08-19    64  50.0
# 5305 2000-11-25    64  50.0
# 5306 2000-12-02    65  49.0
#
# [5307 rows x 6 columns]

# %%
billboard = df # делаю копию

# %%
billboard
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 19663  2000             Lonestar                                 Amazed  4:25
# 19700  2000                Creed                                 Higher  5:16
# 19980  2000             Lonestar                                 Amazed  4:25
# 20017  2000                Creed                                 Higher  5:16
# 20334  2000                Creed                                 Higher  5:16
#
#          genre date.entered date.peaked  week  rank       date
# 0         Rock   2000-09-23  2000-11-18     1  78.0 2000-09-23
# 1         Rock   2000-02-12  2000-04-08     1  15.0 2000-02-12
# 2         Rock   1999-10-23  2000-01-29     1  71.0 1999-10-23
# 3         Rock   2000-08-12  2000-09-16     1  41.0 2000-08-12
# 4         Rock   2000-08-05  2000-10-14     1  57.0 2000-08-05
# ...        ...          ...         ...   ...   ...        ...
# 19663  Country   1999-06-05  2000-03-04    63  45.0 2000-08-12
# 19700     Rock   1999-09-11  2000-07-22    63  50.0 2000-11-18
# 19980  Country   1999-06-05  2000-03-04    64  50.0 2000-08-19
# 20017     Rock   1999-09-11  2000-07-22    64  50.0 2000-11-25
# 20334     Rock   1999-09-11  2000-07-22    65  49.0 2000-12-02
#
# [5307 rows x 10 columns]

# %%
songs = billboard[["year", "artist.inverted", "track", "time", "genre"]] #cоздаем таблицу с песнями без недель и рейтингов
songs
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...     ...                  ...                                    ...   ...
# 19663  2000             Lonestar                                 Amazed  4:25
# 19700  2000                Creed                                 Higher  5:16
# 19980  2000             Lonestar                                 Amazed  4:25
# 20017  2000                Creed                                 Higher  5:16
# 20334  2000                Creed                                 Higher  5:16
#
#          genre
# 0         Rock
# 1         Rock
# 2         Rock
# 3         Rock
# 4         Rock
# ...        ...
# 19663  Country
# 19700     Rock
# 19980  Country
# 20017     Rock
# 20334     Rock
#
# [5307 rows x 5 columns]

# %%
songs = songs.drop_duplicates() #удаляем дубликаты
songs = songs.reset_index(drop=True) #сбрасываем индексы пандаса в этом датафрейме
songs
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
#     genre
# 0    Rock
# 1    Rock
# 2    Rock
# 3    Rock
# 4    Rock
# ..    ...
# 312   R&B
# 313   Rap
# 314  Rock
# 315   Rap
# 316   R&B
#
# [317 rows x 5 columns]

# %%
songs["song_id"] = songs.index # создаем новую колонку, которую заполняем значениями из индексного столбика
songs
# Out:
#      year      artist.inverted                                  track  time  \
# 0    2000      Destiny's Child               Independent Women Part I  3:38
# 1    2000              Santana                           Maria, Maria  4:18
# 2    2000        Savage Garden                     I Knew I Loved You  4:07
# 3    2000              Madonna                                  Music  3:45
# 4    2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ..    ...                  ...                                    ...   ...
# 312  2000     Ghostface Killah                       Cherchez LaGhost  3:04
# 313  2000          Smith, Will                            Freakin' It  3:58
# 314  2000        Zombie Nation                          Kernkraft 400  3:30
# 315  2000       Eastsidaz, The                               Got Beef  3:58
# 316  2000               Fragma                         Toca's Miracle  3:22
#
#     genre  song_id
# 0    Rock        0
# 1    Rock        1
# 2    Rock        2
# 3    Rock        3
# 4    Rock        4
# ..    ...      ...
# 312   R&B      312
# 313   Rap      313
# 314  Rock      314
# 315   Rap      315
# 316   R&B      316
#
# [317 rows x 6 columns]

# %%
songs = songs[['song_id','year', 'artist.inverted', 'track', 'time', 'genre']]
songs
# Out:
#      song_id  year      artist.inverted  \
# 0          0  2000      Destiny's Child
# 1          1  2000              Santana
# 2          2  2000        Savage Garden
# 3          3  2000              Madonna
# 4          4  2000  Aguilera, Christina
# ..       ...   ...                  ...
# 312      312  2000     Ghostface Killah
# 313      313  2000          Smith, Will
# 314      314  2000        Zombie Nation
# 315      315  2000       Eastsidaz, The
# 316      316  2000               Fragma
#
#                                      track  time genre
# 0                 Independent Women Part I  3:38  Rock
# 1                             Maria, Maria  4:18  Rock
# 2                       I Knew I Loved You  4:07  Rock
# 3                                    Music  3:45  Rock
# 4    Come On Over Baby (All I Want Is You)  3:38  Rock
# ..                                     ...   ...   ...
# 312                       Cherchez LaGhost  3:04   R&B
# 313                            Freakin' It  3:58   Rap
# 314                          Kernkraft 400  3:30  Rock
# 315                               Got Beef  3:58   Rap
# 316                         Toca's Miracle  3:22   R&B
#
# [317 rows x 6 columns]

# %%
songs.shape
# Out:
# (317, 6)

# %%
ranks = pd.merge(billboard, songs, on=["year", "artist.inverted", "track", "time", "genre"])
ranks
# Out:
#       year      artist.inverted                                  track  time  \
# 0     2000      Destiny's Child               Independent Women Part I  3:38
# 1     2000              Santana                           Maria, Maria  4:18
# 2     2000        Savage Garden                     I Knew I Loved You  4:07
# 3     2000              Madonna                                  Music  3:45
# 4     2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# ...    ...                  ...                                    ...   ...
# 5302  2000             Lonestar                                 Amazed  4:25
# 5303  2000                Creed                                 Higher  5:16
# 5304  2000             Lonestar                                 Amazed  4:25
# 5305  2000                Creed                                 Higher  5:16
# 5306  2000                Creed                                 Higher  5:16
#
#         genre date.entered date.peaked  week  rank       date  song_id
# 0        Rock   2000-09-23  2000-11-18     1  78.0 2000-09-23        0
# 1        Rock   2000-02-12  2000-04-08     1  15.0 2000-02-12        1
# 2        Rock   1999-10-23  2000-01-29     1  71.0 1999-10-23        2
# 3        Rock   2000-08-12  2000-09-16     1  41.0 2000-08-12        3
# 4        Rock   2000-08-05  2000-10-14     1  57.0 2000-08-05        4
# ...       ...          ...         ...   ...   ...        ...      ...
# 5302  Country   1999-06-05  2000-03-04    63  45.0 2000-08-12        9
# 5303     Rock   1999-09-11  2000-07-22    63  50.0 2000-11-18       46
# 5304  Country   1999-06-05  2000-03-04    64  50.0 2000-08-19        9
# 5305     Rock   1999-09-11  2000-07-22    64  50.0 2000-11-25       46
# 5306     Rock   1999-09-11  2000-07-22    65  49.0 2000-12-02       46
#
# [5307 rows x 11 columns]

# %%
ranks = ranks[["song_id", "date", "week","rank"]]
ranks
# Out:
#       song_id       date  week  rank
# 0           0 2000-09-23     1  78.0
# 1           1 2000-02-12     1  15.0
# 2           2 1999-10-23     1  71.0
# 3           3 2000-08-12     1  41.0
# 4           4 2000-08-05     1  57.0
# ...       ...        ...   ...   ...
# 5302        9 2000-08-12    63  45.0
# 5303       46 2000-11-18    63  50.0
# 5304        9 2000-08-19    64  50.0
# 5305       46 2000-11-25    64  50.0
# 5306       46 2000-12-02    65  49.0
#
# [5307 rows x 4 columns]

# %%
songs

# %% [markdown]
# ## **Проблема: Несколько переменных хранятся в одном столбце.**

# %%
# Генерация исходного датасета с ошибкой
data = {
    "ID": [1, 2],
    "Имя": ["Иван Петров", "Анна Смирнова"],
    "Дата рождения": ["1990-05-12", "1985-11-23"],
    "Контакты": ["ivan@email.com, +79161234567", "anna@mail.com, +79263456789"],
    "Адрес": ["Москва, ул. Ленина, 10", "Санкт-Петербург, Невский, 25"]
}
df = pd.DataFrame(data)
df
# Out:
#    ID            Имя Дата рождения                      Контакты  \
# 0   1    Иван Петров    1990-05-12  ivan@email.com, +79161234567
# 1   2  Анна Смирнова    1985-11-23   anna@mail.com, +79263456789
#
#                           Адрес
# 0        Москва, ул. Ленина, 10
# 1  Санкт-Петербург, Невский, 25

# %%
# Разделение данных
# Разделяем контакты на email и телефон
df[['Email', 'Телефон']] = df['Контакты'].str.split(', ', expand=True)
df
# Out:
#    ID            Имя Дата рождения                      Контакты  \
# 0   1    Иван Петров    1990-05-12  ivan@email.com, +79161234567
# 1   2  Анна Смирнова    1985-11-23   anna@mail.com, +79263456789
#
#                           Адрес           Email       Телефон
# 0        Москва, ул. Ленина, 10  ivan@email.com  +79161234567
# 1  Санкт-Петербург, Невский, 25   anna@mail.com  +79263456789

# %%
# Разделяем адрес на Город, Улицу и Дом
address_split = df['Адрес'].str.split(', ', expand=True)
df[['Город', 'Улица', 'Дом']] = address_split

df
# Out:
#    ID            Имя Дата рождения                      Контакты  \
# 0   1    Иван Петров    1990-05-12  ivan@email.com, +79161234567
# 1   2  Анна Смирнова    1985-11-23   anna@mail.com, +79263456789
#
#                           Адрес           Email       Телефон  \
# 0        Москва, ул. Ленина, 10  ivan@email.com  +79161234567
# 1  Санкт-Петербург, Невский, 25   anna@mail.com  +79263456789
#
#              Город       Улица Дом
# 0           Москва  ул. Ленина  10
# 1  Санкт-Петербург     Невский  25

# %%
# Удаляем старые столбцы
df.drop(columns=['Контакты', 'Адрес'], inplace=True)
df
# Out:
#    ID            Имя Дата рождения           Email       Телефон  \
# 0   1    Иван Петров    1990-05-12  ivan@email.com  +79161234567
# 1   2  Анна Смирнова    1985-11-23   anna@mail.com  +79263456789
#
#              Город       Улица Дом
# 0           Москва  ул. Ленина  10
# 1  Санкт-Петербург     Невский  25

# %% [markdown]
# ## **Проблема: В одной таблице хранятся несколько единиц объектов наблюдения (observational units).**

# %%
import random

# Генерация исходного некорректного датасета (несколько единиц наблюдения в одной таблице)
students = ["Иван Петров", "Мария Смирнова", "Алексей Иванов", "Екатерина Сидорова"]
subjects = ["Математика", "Физика", "История", "Литература"]

data = []
for student in students:
    grades = {subject: random.randint(2, 5) for subject in subjects}
    data.append({"ФИО": student, **grades})

# Создаем DataFrame
incorrect_df = pd.DataFrame(data)
incorrect_df
# Out:
#                   ФИО  Математика  Физика  История  Литература
# 0         Иван Петров           4       4        3           2
# 1      Мария Смирнова           3       2        4           2
# 2      Алексей Иванов           5       4        3           4
# 3  Екатерина Сидорова           2       4        2           3

# %%
# --- Исправление: Разделение на две таблицы ---

# Таблица "Студенты"
students_df = pd.DataFrame({"ID_студента": range(1, len(students) + 1), "ФИО": students})

# Таблица "Оценки" (нормализованная форма)
grades_data = []
for student_id, student in enumerate(students, start=1):
    for subject in subjects:
        grades_data.append({"ID_студента": student_id, "Предмет": subject, "Оценка": random.randint(2, 5)})

grades_df = pd.DataFrame(grades_data)

# %%
students_df
# Out:
#    ID_студента                 ФИО
# 0            1         Иван Петров
# 1            2      Мария Смирнова
# 2            3      Алексей Иванов
# 3            4  Екатерина Сидорова

# %%
grades_df
# Out:
#     ID_студента     Предмет  Оценка
# 0             1  Математика       5
# 1             1      Физика       4
# 2             1     История       3
# 3             1  Литература       2
# 4             2  Математика       5
# 5             2      Физика       3
# 6             2     История       5
# 7             2  Литература       4
# 8             3  Математика       2
# 9             3      Физика       3
# 10            3     История       2
# 11            3  Литература       5
# 12            4  Математика       4
# 13            4      Физика       4
# 14            4     История       5
# 15            4  Литература       2
